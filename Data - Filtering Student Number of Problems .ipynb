# %%
from LSTM import *
from data_getter import *
import matplotlib.pyplot as plt
from IPython import display
import pickle

# %%
directory = 'D:/archive/tensors/data/'

# %%
x = []
y = []
for n in range(0,100,5):
    tensor = get_tensor(directory,students_min=n)
    x.append(n)
    y.append(tensor.shape[0])

# %%
plt.plot(x,y)
plt.title("Number of Data Points")
plt.xlabel("Minimum Problem Attempts")
plt.ylabel("Number of Data Points")
plt.show()

# %%
x = []
y = []
for n in range(0,1000,50):
    tensor = get_tensor(directory,students_min=n)
    x.append(n)
    y.append(tensor.shape[0])

# %%
plt.plot(x,y)
plt.title("Number of Data Points")
plt.xlabel("Minimum Student Attempts")
plt.ylabel("Number of Data Points")
plt.show()
