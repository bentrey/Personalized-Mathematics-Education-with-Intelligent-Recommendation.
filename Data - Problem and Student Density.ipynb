# %%
from data_getter import *
import matplotlib.pyplot as plt

# %%
directory = 'D:/archive/tensors/data/'

# %%
tensor = get_tensor(directory)

# %%
ids, counts = torch.unique(tensor[:,3],return_counts=True)
plt.hist(counts.cpu().numpy(),counts.max().int())
plt.xlim((5, 500))
plt.title('Problem Attempts')
plt.ylabel('Problem Count')
plt.xlabel('Attempts')
plt.show()

# %%
ids, counts = torch.unique(tensor[:,2],return_counts=True)
plt.hist(counts.cpu().numpy(),counts.max().int())
plt.title('Student Problem Count')
plt.ylabel('Student Count')
plt.xlabel('Problems Finished')
plt.xlim((100, 500))
plt.show()
